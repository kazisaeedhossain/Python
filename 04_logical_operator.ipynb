# %%
x = 10 ; y = 5 ; z = 15

result_1 = (x > y) and (x > z)

print("Result 1 = " + str(result_1))


result_2 = (x > y) or (x > z)

print("Result 2 = " + str(result_2))
# Out:
# Result 1 = False
# Result 2 = True
