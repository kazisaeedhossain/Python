# %%
phone_number = 1883
type(phone_number)
# Out:
# int

# %%
age = 20
wieght = 65.5
Name = "Saeed"
is_passed = True

print(type(age),type(wieght),type(Name),type(is_passed))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>

# %%
Name = input("Enter your name: ")
print("Hello, " + Name + "!")
# Out:
# Hello, Kazi Saeed Hossain!
